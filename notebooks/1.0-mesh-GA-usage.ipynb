# %% [markdown]
# ## GA settings

# %%
from src.models.mesh_GA_wrapper import mesh_GA_wrapper

mesh_GA = mesh_GA_wrapper()
# mesh_GA.setRefereneImage(image = "62820.png")
mesh_GA.setRefereneImage(image = "20044.png")
# mesh_GA.setRefereneImage(image = "02000.png")
# mesh_GA.setRefereneImage(image = "02003.png")
# mesh_GA.setRefereneImage(image = "02007.png")
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
ga_params={
    "num_generations":100,
    "num_parents_mating":8,
    "sol_per_pop":16,
    "num_genes":156,
    "parent_selection_type":"sss",
    "keep_parents":4,
    "crossover_type":"single_point",
    "mutation_type":"random",
    "mutation_percent_genes":10,
    "keep_elitism":1,
    "gene_space":{'low': -2, 'high': 2},
}

# mesh_GA.setGeneticAlgorithm(ga_params)

# %% [markdown]
# ## GA run

# %%
mesh_GA.run()
# Out:
# 100%|██████████| 100/100 [05:04<00:00,  3.04s/it]
# Fitness value of the best solution = [-0.00682457 -0.00197068]
# array([-0.00682457, -0.00197068])

# %% [markdown]
# ## Mesh

# %%
parameters=mesh_GA.getMesh(getParams=True,visualize=True)

# %%
neutralmesh=mesh_GA.getNeutralMesh(getParams=False,visualize=True)

# %% [markdown]
# ## Save Mesh

# %%
import open3d as o3d

o3d.io.write_triangle_mesh("my_mesh.obj", neutralmesh[0])
# Out:
# True
