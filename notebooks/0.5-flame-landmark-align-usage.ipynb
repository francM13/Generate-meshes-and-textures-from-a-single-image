# %% [markdown]
# ## Generate Point-cloud

# %%
from src.features.image_to_pointcloud_landmark import image_to_pointcloud_landmark

image = "20044.png"
landmark = image_to_pointcloud_landmark(image, plot_image=False, plot_pointcloud=False)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ## Generate Mesh

# %%
from src.models.flame_interface import flame_interface
import numpy as np

# %%
flame_interface = flame_interface(port=8081)

# shape_params=np.random.rand(1,100)
# pose_params = np.array([[1, 0, 1, np.random.rand(1)[0],0,0]])
# expression_params = np.random.rand(1, 50)


N=1

shape_params=np.ones((1,100))*N
pose_params=np.ones((1,6))*0
expression_params=np.ones((1,50))*N


Flame_vertices, Flame_faces, Flame_landmarks = flame_interface.getFlame(shape_params=shape_params,pose_params=pose_params,expression_params=expression_params)

# %%
from src.features.flame_mesh import flame_mesh
Mesh=flame_mesh(Flame_vertices,Flame_faces,Flame_landmarks)
Flame_landmarks=Mesh[1]
Mesh=Mesh[0]

# %% [markdown]
# ## Align Usage

# %%
from src.features.face_landmark_alignment import face_landmark_alignment
face_landmark_alignment(Flame_landmarks,landmark)

# %%
from src.visualization.visualize_mesh import visualize_mesh
visualize_mesh([Mesh,Flame_landmarks,landmark])
