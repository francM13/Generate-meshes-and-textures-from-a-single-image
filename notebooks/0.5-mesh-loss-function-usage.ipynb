# %% [markdown]
# ## Landmark

# %%
from src.features.image_to_pointcloud_landmark import image_to_pointcloud_landmark

image = "20044.png"
landmark = image_to_pointcloud_landmark(image, plot_image=False, plot_pointcloud=False)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ## Flame Mesh

# %%
from src.features.generate_flame_mesh import generate_flame_mesh
import numpy as np

shape_params=np.random.rand(1,100)
pose_params = np.array([[1, 0, 1, np.random.rand(1)[0],0,0]])
expression_params = np.random.rand(1, 50)

Mesh,Flame_landmarks=generate_flame_mesh(shape_params,pose_params,expression_params)

# %% [markdown]
# ## Calculate Loss Function

# %%
from src.data.mesh_loss_function import mesh_loss_function
loss=mesh_loss_function(Mesh,Flame_landmarks,landmark,True,apply_loss=["landmarks","mesh","pointclouds"],reduce_landmarks=False)
print("Loss Results: ",loss)
# Out:
# Loss Results:  {'landmarks': 0.027084614036217477, 'mesh': 0.0053251996, 'pointclouds': 0.0209864681081816}

# %%
from src.data.mesh_loss_function import mesh_loss_function
loss=mesh_loss_function(Mesh,Flame_landmarks,landmark,apply_loss=["landmarks","mesh","pointclouds"],reduce_landmarks=True)
print("Loss Results: ",loss)
# Out:
# Loss Results:  {'landmarks': 0.027084614036217477, 'mesh': 0.0050659515, 'pointclouds': 0.022890178588714845}
